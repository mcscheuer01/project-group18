# %%
print("Hello! Welcome to our final project for IST 256! We have created a program that calculates both the time difference and flight duration between two locations from the list below.")
print("Make sure to input in the same format as the list: City, ST")
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

site_id = pd.read_csv('site_ids.csv')
site_id
# Out:
# Hello! Welcome to our final project for IST 256! We have created a program that calculates both the time difference and flight duration between two locations from the list below.
# Make sure to input in the same format as the list: City, ST
#     site_id             location country        lat        long  \
# 0         0          Orlando, FL      US  28.540000  -81.380000
# 1         1      Southampton, UK      UK  50.900000   -1.400000
# 2         2             Tempe,AZ      US  33.412778 -111.943056
# 3         3       Washington, DC      US  38.904722  -77.016389
# 4         4         Berkeley, CA      US  37.871667 -122.272778
# 5         5      Southampton, UK      UK  50.900000   -1.400000
# 6         6     Philadelphia, PA      US  39.952778  -75.163611
# 7         7         Montreal, QC      CA  45.508889  -73.561667
# 8         8          Orlando, FL      US  28.540000  -81.380000
# 9         9           Austin, TX      US  30.266667  -97.733333
# ...

# %%
choices = ['Orlando, FL','Southampton, UK','Tempe,AZ',"Washington, DC","Berkeley, CA","Southampton, UK","Philadelphia, PA","Montreal, QC","Orlando, FL","Austin, TX","Las Vegas, NV","Ottawa, ON","Dublin, IE","Twin Cities, MN","Charlottesville, VA","Rochester, NY",]
#DEFINE VARIABLES FOR INPUT
choice_1 = input("Enter a first location: ")
choice_2 = input("Enter a second location: ")
#IF LOOP TO CHECK THAT INPUT IS IN LIST OF CITIES
if (choice_1,choice_2 in choices):  
    print("You chose %s and %s" % (choice_1,choice_2))

#ALL COMBINATIONS STARTING WITH ORLANDO, FL
    if (choice_1 == 'Orlando, FL' and choice_2 == 'Orlando, FL'):
        print("The time difference is 0 hours and the flight duration is 0 hours.")
    elif (choice_1 == 'Orlando, FL' and choice_2 == 'Southampton, UK'):
        print("The time difference is 5 hours and the flight duration is 9 hours.")
    elif (choice_1 == 'Orlando, FL' and choice_2 == 'Tempe, AZ'):
        print("The time difference is 3 hours and the flight duration is 4.5 hours.")
    elif (choice_1 == 'Orlando, FL' and choice_2 == 'Washington, DC'):
        print("The time difference is 0 hours and the flight duration is 2 hours.")
    elif (choice_1 == 'Orlando, FL' and choice_2 == 'Berkeley, CA'):
        print("The time difference is 3 hours and the flight duration is 6 hours.")
    elif (choice_1 == 'Orlando, FL' and choice_2 == 'Southampton, UK'):
        print("The time difference is 5 hours and the flight duration is 9 hours.")
    elif (choice_1 == 'Orlando, FL' and choice_2 == 'Philadelphia, PA'):
        print("The time difference is 0 hours and the flight duration is 2 hours.")
    elif (choice_1 == 'Orlando, FL' and choice_2 == 'Montreal, QC'):
        print("The time difference is 0 hours and the flight duration is 3 hours.")
    elif (choice_1 == 'Orlando, FL' and choice_2 == 'Orlando, FL'):
        print("The time difference is 0 hours and the flight duration is 0 hours.")
    elif (choice_1 == 'Orlando, FL' and choice_2 == 'Austin, TX'):
        print("The time difference is 1 hour and the flight duration is 2.5 hours.")
    elif (choice_1 == 'Orlando, FL' and choice_2 == 'Las Vegas, NV'):
        print("The time difference is 3 hours and the flight duration is 5 hours.")
    elif (choice_1 == 'Orlando, FL' and choice_2 == 'Ottawa, ON'):
        print("The time difference is 0 hours and the flight duration is 14 hours.")
    elif (choice_1 == 'Orlando, FL' and choice_2 == 'Dublin, IE'):
        print("The time difference is 5 hours and the flight duration is 8.6 hours.")
    elif (choice_1 == 'Orlando, FL' and choice_2 == 'Twin Cities, MN'):
        print("The time difference is 1 hour and the flight duration is 3.5 hours.")
    elif (choice_1 == 'Orlando, FL' and choice_2 == 'Charlottesville, VA'):
        print("The time difference is 0 hours and the flight duration is 1.75 hours.")
    elif (choice_1 == 'Orlando, FL' and choice_2 == 'Rochester, NY'):
        print("The time difference is 0 hours and the flight duration is 2.5 hours.")
  #ALL COMBINATIONS STARTING WITH SOUTHAMPTON, UK
    elif (choice_1 == 'Southampton, UK' and choice_2 == 'Orlando, FL'):
        print("The time difference is 5 hours and the flight duration is 9 hours.")
    elif (choice_1 == 'Southampton, UK' and choice_2 == 'Southampton, UK'):
        print("The time difference is 0 hours and the flight duration is 0 hours.")
    elif (choice_1 == 'Southampton, UK' and choice_2 == 'Tempe, AZ'):
        print("The time difference is 8 hours and the flight duration is 12 hours.")
    elif (choice_1 == 'Southampton, UK' and choice_2 == 'Washington, DC'):
        print("The time difference is 5 hours and the flight duration is 8.3 hours.")
    elif (choice_1 == 'Southampton, UK' and choice_2 == 'Berkeley, CA'):
        print("The time difference is 8 hours and the flight duration is 12 hours.")
    elif (choice_1 == 'Southampton, UK' and choice_2 == 'Philadelphia, PA'):
        print("The time difference is 5 hours and the flight duration is 8 hours.")
    elif (choice_1 == 'Southampton, UK' and choice_2 == 'Montreal, QC'):
        print("The time difference is 5 hours and the flight duration is 7.25 hours.")
    elif (choice_1 == 'Southampton, UK' and choice_2 == 'Orlando, FL'):
        print("The time difference is 5 hours and the flight duration is 9 hours.")
    elif (choice_1 == 'Southampton, UK' and choice_2 == 'Austin, TX'):
        print("The time difference is 6 hours and the flight duration is 11 hours.")
    elif (choice_1 == 'Southampton, UK' and choice_2 == 'Las Vegas, NV'):
        print("The time difference is 8 hours and the flight duration is 12 hours.")
    elif (choice_1 == 'Southampton, UK' and choice_2 == 'Ottawa, ON'):
        print("The time difference is 5 hours and the flight duration is 7 hours.")
    elif (choice_1 == 'Southampton, UK' and choice_2 == 'Dublin, IE'):
        print("The time difference is 0 hours and the flight duration is 1 hours.")
    elif (choice_1 == 'Southampton, UK' and choice_2 == 'Twin Cities, MN'):
        print("The time difference is 6 hours and the flight duration is 9.5 hours.")
    elif (choice_1 == 'Southampton, UK' and choice_2 == 'Charlottesville, VA'):
        print("The time difference is 5 hours and the flight duration is 8.3 hours.")
    elif (choice_1 == 'Southampton, UK' and choice_2 == 'Rochester, NY'):
        print("The time difference is 5 hours and the flight duration is 7.75 hours.")
#ALL COMBINATIONS STARTING WITH TEMPE, AZ
    elif (choice_1 == 'Tempe, AZ' and choice_2 == 'Orlando, FL'):
        print("The time difference is 3 hours and the flight duration is 4.5 hours.")
    elif (choice_1 == 'Tempe, AZ' and choice_2 == 'Southampton, UK'):
        print("The time difference is 8 hours and the flight duration is 12 hours.")
    elif (choice_1 == 'Tempe, AZ' and choice_2 == 'Tempe, AZ'):
        print("The time difference is 0 hours and the flight duration is 0 hours.")
    elif (choice_1 == 'Tempe, AZ' and choice_2 == 'Washington, DC'):
        print("The time difference is 3 hours and the flight duration is 4 hours.")
    elif (choice_1 == 'Tempe, AZ' and choice_2 == 'Berkeley, CA'):
        print("The time difference is 0 hours and the flight duration is 2 hours.")
    elif (choice_1 == 'Tempe, AZ' and choice_2 == 'Philadelphia, PA'):
        print("The time difference is 3 hours and the flight duration is 4 hours.")
    elif (choice_1 == 'Tempe, AZ' and choice_2 == 'Montreal, QC'):
        print("The time difference is 3 hours and the flight duration is 4.25 hours.")
    elif (choice_1 == 'Tempe, AZ' and choice_2 == 'Austin, TX'):
        print("The time difference is 2 hours and the flight duration is 2 hours.")
    elif (choice_1 == 'Tempe, AZ' and choice_2 == 'Las Vegas, NV'):
        print("The time difference is 0 hours and the flight duration is 1 hours.")
    elif (choice_1 == 'Tempe, AZ' and choice_2 == 'Ottawa, ON'):
        print("The time difference is 3 hours and the flight duration is 15 hours.")
    elif (choice_1 == 'Tempe, AZ' and choice_2 == 'Dublin, IE'):
        print("The time difference is 8 hours and the flight duration is 10.25 hours.")
    elif (choice_1 == 'Tempe, AZ' and choice_2 == 'Twin Cities, MN'):
        print("The time difference is 2 hours and the flight duration is 3 hours.")
    elif (choice_1 == 'Tempe, AZ' and choice_2 == 'Charlottesville, VA'):
        print("The time difference is 3 hours and the flight duration is 3.75 hours.")
    elif (choice_1 == 'Tempe, AZ' and choice_2 == 'Rochester, NY'):
        print("The time difference is 3 hours and the flight duration is 4 hours.")
#ALL COMBINATIONS STARTING WITH WASHINGTON, DC
    elif (choice_1 == 'Washington, DC' and choice_2 == 'Orlando, FL'):
        print("The time difference is 0 hours and the flight duration is 2 hours.")
    elif (choice_1 == 'Washington, DC' and choice_2 == 'Southampton, UK'):
        print("The time difference is 5 hours and the flight duration is 8.3 hours.")
    elif (choice_1 == 'Washington, DC' and choice_2 == 'Tempe, AZ'):
        print("The time difference is 3 hours and the flight duration is 4 hours.")
    elif (choice_1 == 'Washington, DC' and choice_2 == 'Washington, DC'):
        print("The time difference is 0 hours and the flight duration is 0 hours.")
    elif (choice_1 == 'Washington, DC' and choice_2 == 'Berkeley, CA'):
        print("The time difference is 3 hours and the flight duration is 7 hours.")
    elif (choice_1 == 'Washington, DC' and choice_2 == 'Philadelphia, PA'):
        print("The time difference is 0 hours and the flight duration is 0.5 hours.")
    elif (choice_1 == 'Washington, DC' and choice_2 == 'Montreal, QC'):
        print("The time difference is 0 hours and the flight duration is 1.3 hours.")
    elif (choice_1 == 'Washington, DC' and choice_2 == 'Austin, TX'):
        print("The time difference is 1 hour and the flight duration is 3.25 hours.")
    elif (choice_1 == 'Washington, DC' and choice_2 == 'Las Vegas, NV'):
        print("The time difference is 3 hours and the flight duration is 5.6 hours.")
    elif (choice_1 == 'Washington, DC' and choice_2 == 'Ottawa, ON'):
        print("The time difference is 0 hours and the flight duration is 13 hours.")
    elif (choice_1 == 'Washington, DC' and choice_2 == 'Dublin, IE'):
        print("The time difference is 5 hours and the flight duration is 7.3 hours.")
    elif (choice_1 == 'Washington, DC' and choice_2 == 'Twin Cities, MN'):
        print("The time difference is 1 hour and the flight duration is 3 hours.")
    elif (choice_1 == 'Washington, DC' and choice_2 == 'Charlottesville, VA'):
        print("The time difference is 0 hours and the flight duration is 0.5 hours.")
    elif (choice_1 == 'Washington, DC' and choice_2 == 'Rochester, NY'):
        print("The time difference is 0 hours and the flight duration is 1 hour.")
#ALL COMBINATIONS STARTING WITH BERKELEY, CA
    elif (choice_1 == 'Berkeley, CA' and choice_2 == 'Orlando, FL'):
        print("The time difference is 3 hours and the flight duration is 6 hours.")
    elif (choice_1 == 'Berkeley, CA' and choice_2 == 'Southampton, UK'):
        print("The time difference is 8 hours and the flight duration is 12 hours.")
    elif (choice_1 == 'Berkeley, CA' and choice_2 == 'Tempe, AZ'):
        print("The time difference is 0 hours and the flight duration is 2 hours.")
    elif (choice_1 == 'Berkeley, CA' and choice_2 == 'Washington, DC'):
        print("The time difference is 3 hours and the flight duration is 7 hours.")
    elif (choice_1 == 'Berkeley, CA' and choice_2 == 'Berkeley, CA'):
        print("The time difference is 0 hours and the flight duration is 0 hours.")
    elif (choice_1 == 'Berkeley, CA' and choice_2 == 'Philadelphia, PA'):
        print("The time difference is 3 hours and the flight duration is 4.6 hours.")
    elif (choice_1 == 'Berkeley, CA' and choice_2 == 'Montreal, QC'):
        print("The time difference is 3 hours and the flight duration is 5 hours.")
    elif (choice_1 == 'Berkeley, CA' and choice_2 == 'Austin, TX'):
        print("The time difference is 2 hours and the flight duration is 3 hours.")
    elif (choice_1 == 'Berkeley, CA' and choice_2 == 'Las Vegas, NV'):
        print("The time difference is 0 hours and the flight duration is 1 hours.")
    elif (choice_1 == 'Berkeley, CA' and choice_2 == 'Ottawa, ON'):
        print("The time difference is 3 hours and the flight duration is 14 hours.")
    elif (choice_1 == 'Berkeley, CA' and choice_2 == 'Dublin, IE'):
        print("The time difference is 8 hours and the flight duration is 10.5 hours.")
    elif (choice_1 == 'Berkeley, CA' and choice_2 == 'Twin Cities, MN'):
        print("The time difference is 2 hours and the flight duration is 3 hours.")
    elif (choice_1 == 'Berkeley, CA' and choice_2 == 'Charlottesville, VA'):
        print("The time difference is 3 hours and the flight duration is 4.5 hours.")
    elif (choice_1 == 'Berkeley, CA' and choice_2 == 'Rochester, NY'):
        print("The time difference is 3 hours and the flight duration is 4.5 hours.")
#ALL COMBINATIONS STARTING WITH PHILADELPHIA, PA
    elif (choice_1 == 'Philadelphia, PA' and choice_2 == 'Orlando, FL'):
        print("The time difference is 0 hours and the flight duration is 2 hours.")
    elif (choice_1 == 'Philadelphia, PA' and choice_2 == 'Southampton, UK'):
        print("The time difference is 5 hours and the flight duration is 8 hours.")
    elif (choice_1 == 'Philadelphia, PA' and choice_2 == 'Tempe, AZ'):
        print("The time difference is 3 hours and the flight duration is 4 hours.")
    elif (choice_1 == 'Philadelphia, PA' and choice_2 == 'Washington, DC'):
        print("The time difference is 0 hours and the flight duration is 0.5 hours.")
    elif (choice_1 == 'Philadelphia, PA' and choice_2 == 'Berkeley, CA'):
        print("The time difference is 3 hours and the flight duration is 4.6 hours.")
    elif (choice_1 == 'Philadelphia, PA' and choice_2 == 'Philadelphia, PA'):
        print("The time difference is 0 hours and the flight duration is 0 hours.")
    elif (choice_1 == 'Philadelphia, PA' and choice_2 == 'Montreal, QC'):
        print("The time difference is 0 hours and the flight duration is 1 hours.")
    elif (choice_1 == 'Philadelphia, PA' and choice_2 == 'Austin, TX'):
        print("The time difference is 1 hour and the flight duration is 3.5 hours.")
    elif (choice_1 == 'Philadelphia, PA' and choice_2 == 'Las Vegas, NV'):
        print("The time difference is 3 hours and the flight duration is 6 hours.")
    elif (choice_1 == 'Philadelphia, PA' and choice_2 == 'Ottawa, ON'):
        print("The time difference is 0 hours and the flight duration is 12.75 hours.")
    elif (choice_1 == 'Philadelphia, PA' and choice_2 == 'Dublin, IE'):
        print("The time difference is 5 hours and the flight duration is 7 hours.")
    elif (choice_1 == 'Philadelphia, PA' and choice_2 == 'Twin Cities, MN'):
        print("The time difference is 1 hour and the flight duration is 3 hours.")
    elif (choice_1 == 'Philadelphia, PA' and choice_2 == 'Charlottesville, VA'):
        print("The time difference is 0 hours and the flight duration is 1 hours.")
    elif (choice_1 == 'Philadelphia, PA' and choice_2 == 'Rochester, NY'):
        print("The time difference is 0 hours and the flight duration is 1 hour.")
#ALL COMBINATIONS STARTING WITH MONTREAL, QC
    elif (choice_1 == 'Montreal, QC' and choice_2 == 'Orlando, FL'):
        print("The time difference is 0 hours and the flight duration is 3 hours.")
    elif (choice_1 == 'Montreal, QC' and choice_2 == 'Southampton, UK'):
        print("The time difference is 5 hours and the flight duration is 7.25 hours.")
    elif (choice_1 == 'Montreal, QC' and choice_2 == 'Tempe, AZ'):
        print("The time difference is 3 hours and the flight duration is 4.25 hours.")
    elif (choice_1 == 'Montreal, QC' and choice_2 == 'Washington, DC'):
        print("The time difference is 0 hours and the flight duration is 1.3 hours.")
    elif (choice_1 == 'Montreal, QC' and choice_2 == 'Berkeley, CA'):
        print("The time difference is 3 hours and the flight duration is 5 hours.")
    elif (choice_1 == 'Montreal, QC' and choice_2 == 'Philadelphia, PA'):
        print("The time difference is 0 hours and the flight duration is 1 hour.")
    elif (choice_1 == 'Montreal, QC' and choice_2 == 'Montreal, QC'):
        print("The time difference is 0 hours and the flight duration is 0 hours.")
    elif (choice_1 == 'Montreal, QC' and choice_2 == 'Austin, TX'):
        print("The time difference is 1 hour and the flight duration is 4 hours.")
    elif (choice_1 == 'Montreal, QC' and choice_2 == 'Las Vegas, NV'):
        print("The time difference is 3 hours and the flight duration is 6 hours.")
    elif (choice_1 == 'Montreal, QC' and choice_2 == 'Ottawa, ON'):
        print("The time difference is 0 hours and the flight duration is 12 hours.")
    elif (choice_1 == 'Montreal, QC' and choice_2 == 'Dublin, IE'):
        print("The time difference is 5 hours and the flight duration is 6.5 hours.")
    elif (choice_1 == 'Montreal, QC' and choice_2 == 'Twin Cities, MN'):
        print("The time difference is 1 hour and the flight duration is 2.5 hours.")
    elif (choice_1 == 'Montreal, QC' and choice_2 == 'Charlottesville, VA'):
        print("The time difference is 0 hours and the flight duration is 1.5 hours.")
    elif (choice_1 == 'Montreal, QC' and choice_2 == 'Rochester, NY'):
        print("The time difference is 0 hours and the flight duration is 1 hour.")
    #ALL COMBOS STARTING WITH AUSTIN, TX     
    elif(choice_1 == 'Austin, TX' and choice_2 == 'Twin Cities, MN'):
        print("The time difference is 0 hours and the flight duration is 2.25 hours.")
    elif(choice_1 == 'Austin, TX' and choice_2 == 'Las Vegas, NV'):
        print("The time difference is 2 hours and the flight duration is 3 hours.")
    elif(choice_1 == 'Austin,TX' and choice_2 == 'Orlando, FL'):
        print("The time difference is 1 hours and the flight duration is 2.5 hours.")
    elif(choice_1 == 'Austin, TX' and choice_2 == 'Dublin, IE'):
        print("The time difference is 6 hours and the flight duration is 9.75 hours.")    
    elif(choice_1 == 'Austin, TX' and choice_2 == 'Rochester'):
        print("The time difference is 1 hour and the flight duration is 3 hours.")    
    elif(choice_1 == 'Austin, TX' and choice_2 == 'Charlottesville, VA'):
        print("The time difference is 1 hour and the flight duration is 2.6 hours.")    
    elif(choice_1 == 'Austin, TX' and choice_2 == 'Montreal, QC'):
        print("The time difference is 1 hour and the flight duration is 4 hours.")    
    elif(choice_1 == 'Austin, TX' and choice_2 == 'Berkeley, CA'):
        print("The time difference is 62 hours and the flight duration is 3 hours.")    
    elif(choice_1 == 'Austin, TX' and choice_2 == 'Tempe, AZ'):
        print("The time difference is 2 hours and the flight duration is 2 hours.")    
    elif(choice_1 == 'Austin, TX' and choice_2 == 'Philadelphia, PA'):
        print("The time difference is 1 hour and the flight duration is 3.5 hours.")    
    elif(choice_1 == 'Austin, TX' and choice_2 == 'Washington, DC'):
        print("The time difference is 1 hour and the flight duration is 3.25 hours.")
    elif(choice_1 == 'Austin, TX' and choice_2 == 'Southampton, UK'):
        print("The time difference is 6 hours and the flight duration is 11 hours.")
    elif(choice_1 == 'Austin, TX' and choice_2 == 'Southampton, UK'):
        print("The time difference is 6 hours and the flight duration is 11 hours.")
    elif(choice_1 == 'Austin, TX' and choice_2 == 'Orlando, FL'):
        print("The time difference is 1 hours and the flight duration is 2.5 hours.")
    elif(choice_1 == 'Austin, TX' and choice_2 == 'Austin, TX'):
        print("The time difference is 0 hours and the flight duration is 0 hours.")
    elif(choice_1 == 'Austin, TX' and choice_2 == 'Ottawa, ON'):
        print("The time difference is 1 hour and the flight duration is 15 hours.")
#ALL COMBOS STARTING WITH DUBLIN, IE
    elif(choice_1 == 'Dublin, IE' and choice_2 == 'Austin, TX'):
        print("The time difference is 6 hours and the flight duration is 9.75 hours.")
    elif(choice_1 == 'Dublin, IE' and choice_2 == 'Orlando, FL'):
        print("The time difference is 5 hours and the flight duration is 8.6 hours.")
    elif (choice_1 == 'Dublin, IE' and choice_2 == 'Southampton, UK'):
        print("The time difference is 0 hours and the flight duration is 1 hour.")
    elif (choice_1 == 'Dublin, IE' and choice_2 == 'Tempe, AZ'):
        print("The time difference is 8 hours and the flight duration is 10.25 hours.")
    elif (choice_1 == 'Dublin, IE' and choice_2 == 'Washington, DC'):
        print("The time difference is 5 hours and the flight duration is 7.3 hours.")
    elif (choice_1 == 'Dublin, IE' and choice_2 == 'Berkeley, CA'):
        print("The time difference is 8 hours and the flight duration is 10.5 hours.")
    elif (choice_1 == 'Dublin, IE' and choice_2 == 'Philadelphia, PA'):
        print("The time difference is 5 hours and the flight duration is 7 hours.")
    elif (choice_1 == 'Dublin, IE' and choice_2 == 'Montreal, QC'):
        print("The time difference is 5 hours and the flight duration is 6.5 hours.")
    elif (choice_1 == 'Dublin, IE' and choice_2 == 'Las Vegas, NV'):
        print("The time difference is 8 hours and the flight duration is 10 hours.")
    elif (choice_1 == 'Dublin, IE' and choice_2 == 'Ottawa, ON'):
        print("The time difference is 5 hours and the flight duration is 8. hours.")
    elif (choice_1 == 'Dublin, IE' and choice_2 == 'Twin Cities, MN'):
        print("The time difference is 6 hours and the flight duration is 8.5 hours.")
    elif (choice_1 == 'Dublin, IE' and choice_2 == 'Charlottesville, VA'):
        print("The time difference is 5 hours and the flight duration is 7.75 hours.")
    elif (choice_1 == 'Dublin, IE' and choice_2 == 'Rochester, NY'):
        print("The time difference is 5 hours and the flight duration is 7 hours.")
    elif (choice_1 == 'Dublin, IE' and choice_2 == 'Orlando, FL'):
        print("The time difference is 5 hours and the flight duration is 8.6 hours.")
    elif (choice_1 == 'Dublin, IE' and choice_2 == 'Southampton, UK'):
        print("The time difference is 0 hours and the flight duration is 1 hour.")
    elif (choice_1 == 'Dublin, IE' and choice_2 == 'Dublin, IE'):
        print("The time difference is 0 hours and the flight duration is 0 hours.")
#ALL COMBOS STARTING WITH ROCHESTER, NY
    elif (choice_1 == 'Rochester, NY' and choice_2 == 'Orlando, FL'):
        print("The time difference is 0 hours and the flight duration is 2.5 hours.")
    elif (choice_1 == 'Rochester, NY' and choice_2 == 'Southampton, UK'):
        print("The time difference is 5 hours and the flight duration is 7.75 hours.")
    elif (choice_1 == 'Rochester, NY' and choice_2 == 'Tempe, AZ'):
        print("The time difference is 3 hours and the flight duration is 4 hours.")
    elif (choice_1 == 'Rochester, NY' and choice_2 == 'Washington, DC'):
        print("The time difference is 0 hours and the flight duration is 1 hour.")
    elif (choice_1 == 'Rochester, NY' and choice_2 == 'Berkeley, CA'):
        print("The time difference is 3 hours and the flight duration is 4.5 hours.")
    elif (choice_1 == 'Rochester, NY' and choice_2 == 'Philadelphia, PA'):
        print("The time difference is 0 hours and the flight duration is 1 hour.")
    elif (choice_1 == 'Rochester, NY' and choice_2 == 'Southampton, UK'):
        print("The time difference is 5 hours and the flight duration is 7.75 hours.")
    elif (choice_1 == 'Rochester, NY' and choice_2 == 'Orlando, FL'):
        print("The time difference is 0 hours and the flight duration is 2.5 hours.")
    elif (choice_1 == 'Rochester, NY' and choice_2 == 'Austin, TX'):
        print("The time difference is 0 hours and the flight duration is 3 hours.")
    elif (choice_1 == 'Rochester, NY' and choice_2 == 'Las Vegas, NV'):
        print("The time difference is 3 hours and the flight duration is 4 hours.")
    elif (choice_1 == 'Rochester, NY' and choice_2 == 'Ottawa, ON'):
        print("The time difference is 0 hours and the flight duration is 14 hours.")
    elif (choice_1 == 'Rochester, NY' and choice_2 == 'Dublin, IE'):
        print("The time difference is 5 hours and the flight duration is 7 hours.")
    elif (choice_1 == 'Rochester, NY' and choice_2 == 'Twin Cities, MN'):
        print("The time difference is 1 hour and the flight duration is 1.6 hours.")
    elif (choice_1 == 'Rochester, NY' and choice_2 == 'Charlottesville, VA'):
        print("The time difference is 0 hours and the flight duration is 1 hours.")
    elif (choice_1 == 'Rochester, NY' and choice_2 == 'Rochester, NY'):
        print("The time difference is 0 hours and the flight duration is 0 hours.")
#ALL COMBOS STARTING WITH LAS VEGAS, NV
    elif(choice_1 == 'Las Vegas, NV' and choice_2 == 'Orlando, FL'):
        print("The time difference is 3 hours and the flight duration is 5 hours.")
    elif(choice_1 == 'Las Vegas, NV' and choice_2 == 'Southampton, UK'):
        print("The time difference is 8 hours and the flight duration is 12 hours.")
    elif(choice_1 == 'Las Vegas, NV' and choice_2 == 'Tempe, AZ'):
        print("The time difference is 0 hours and the flight duration is 1 hours.")
    elif(choice_1 == 'Las Vegas, NV' and choice_2 == 'Washington, DC'):
        print("The time difference is 3 hours and the flight duration is 5.6 hours.")
    elif(choice_1 == 'Las Vegas, NV' and choice_2 == 'Berkeley, CA'):
        print("The time difference is 0 hours and the flight duration is 1 hour.")
    elif(choice_1 == 'Las Vegas, NV' and choice_2 == 'Southampton, UK'):
        print("The time difference is 8 hours and the flight duration is 12 hours.")
    elif(choice_1 == 'Las Vegas, NV' and choice_2 == 'Philadelphia, PA'):
        print("The time difference is 3 hours and the flight duration is 6 hours.")
    elif(choice_1 == 'Las Vegas, NV' and choice_2 == 'Montreal, QC'):
        print("The time difference is 3 hours and the flight duration is 6 hours.")
    elif(choice_1 == 'Las Vegas, NV' and choice_2 == 'Orlando, FL'):
        print("The time difference is 3 hours and the flight duration is 5 hours.")
    elif(choice_1 == 'Las Vegas, NV' and choice_2 == 'Austin, TX'):
        print("The time difference is 2 hours and the flight duration is 3 hours.")
    elif(choice_1 == 'Las Vegas, NV' and choice_2 == 'Ottawa, ON'):
        print("The time difference is 2 hours and the flight duration is 14.5 hours.")
    elif(choice_1 == 'Las Vegas, NV' and choice_2 == 'Las Vegas, NV'):
        print("The time difference is 0 hours and the flight duration is 0 hours.")
    elif(choice_1 == 'Las Vegas, NV' and choice_2 == 'Dublin, IE'):
        print("The time difference is 8 hours and the flight duration is 10 hours.")
    elif(choice_1 == 'Las Vegas, NV' and choice_2 == 'Charlottesville, VA'):
        print("The time difference is 3 hours and the flight duration is 4 hours.")
    elif(choice_1 == 'Las Vegas, NV' and choice_2 == 'Rochester, NY'):
        print("The time difference is 3 hours and the flight duration is 4 hours.")
#ALL COMBOS STARTING WITH TWIN CITIES, MN
    elif(choice_1 == 'Twin Cities, MN' and choice_2 == 'Twin Cities, MN'):
        print("The time difference is 0 hours and the flight duration is 0 hours.")
    elif(choice_1 == 'Twin Cities, MN' and choice_2 == 'Orlando, FL'):
        print("The time difference is 1 hours and the flight duration is 3.5 hours.")
    elif(choice_1 == 'Twin Cities, MN' and choice_2 == 'Southampton, UK'):
        print("The time difference is 6 hours and the flight duration is 9.5 hours.")
    elif(choice_1 == 'Twin Cities, MN' and choice_2 == 'Washington, DC'):
        print("The time difference is 1 hour and the flight duration is 3 hours.")
    elif(choice_1 == 'Twin Cities, MN' and choice_2 == 'Tempe, AZ'):
        print("The time difference is 2 hours and the flight duration is 3 hours.")
    elif(choice_1 == 'Twin Cities, MN' and choice_2 == 'Berkeley, CA'):
        print("The time difference is 2 hours and the flight duration is 3 hours.")
    elif(choice_1 == 'Twin Cities, MN' and choice_2 == 'Philadelphia, PA'):
        print("The time difference is 2 hours and the flight duration is 3 hours.")
    elif(choice_1 == 'Twin Cities, MN' and choice_2 == 'Southampton, UK'):
        print("The time difference is 6 hours and the flight duration is 9.5 hours.")
    elif(choice_1 == 'Twin Cities, MN' and choice_2 == 'Montreal, QC'):
        print("The time difference is 1 hour and the flight duration is 2.5 hours.")
    elif(choice_1 == 'Twin Cities, MN' and choice_2 == 'Austin, TX'):
        print("The time difference is 0 hours and the flight duration is 2.25 hours.")
    elif(choice_1 == 'Twin Cities, MN' and choice_2 == 'Orlando, FL'):
        print("The time difference is 1 hour and the flight duration is 3.5 hours.")
    elif(choice_1 == 'Twin Cities, MN' and choice_2 == 'Las Vegas, NV'):
        print("The time difference is 2 hours and the flight duration is 2.5 hours.")
    elif(choice_1 == 'Twin Cities, MN' and choice_2 == 'Ottawa, ON'):
        print("The time difference is 1 hour and the flight duration is 13.75 hours.")
    elif(choice_1 == 'Twin Cities, MN' and choice_2 == 'Dublin, IE'):
        print("The time difference is 6 hours and the flight duration is 8.5 hours.")
    elif(choice_1 == 'Twin Cities, MN' and choice_2 == 'Charlottesville, VA'):
        print("The time difference is 1 hour and the flight duration is 2 hours.")
    elif(choice_1 == 'Twin Cities, MN' and choice_2 == 'Rochester, NY'):
        print("The time difference is 1 hour and the flight duration is 1.6 hours.")
#ALL COMBOS STARTING WITH CHARLOTTESVILLE, VA
    elif(choice_1 == 'Charlottesville, VA' and choice_2 == 'Charlottesville, VA'):
        print("The time difference is 0 hours and the flight duration is 0 hours.")
    elif(choice_1 == 'Charlottesville, VA' and choice_2 == 'Orlando, FL'):
        print("The time difference is 0 hours and the flight duration is 1.75 hours.")
    elif(choice_1 == 'Charlottesville, VA' and choice_2 == 'Tempe, AZ'):
        print("The time difference is 3 hours and the flight duration is 3.75 hours.")
    elif(choice_1 == 'Charlottesville, VA' and choice_2 == 'Washington, DC'):
        print("The time difference is 0 hours and the flight duration is .5 hours.")
    elif(choice_1 == 'Charlottesville, VA' and choice_2 == 'Berkeley, CA'):
        print("The time difference is 3 hours and the flight duration is 4.5 hours.")
    elif(choice_1 == 'Charlottesville, VA' and choice_2 == 'Southampton, UK'):
        print("The time difference is 5 hours and the flight duration is 8.3 hours.")
    elif(choice_1 == 'Charlottesville, VA' and choice_2 == 'Philadelphia, PA'):
        print("The time difference is 0 hours and the flight duration is 1 hour.")
    elif(choice_1 == 'Charlottesville, VA' and choice_2 == 'Montreal, QC'):
        print("The time difference is 0 hours and the flight duration is 1.5 hours.")
    elif(choice_1 == 'Charlottesville, VA' and choice_2 == 'Austin, TX'):
        print("The time difference is 1 hour and the flight duration is 2.6 hours.")
    elif(choice_1 == 'Charlottesville, VA' and choice_2 == 'Orlando, FL'):
        print("The time difference is 0 hours and the flight duration is 1.75 hours.")
    elif(choice_1 == 'Charlottesville, VA' and choice_2 == 'Las Vegas, NV'):
        print("The time difference is 3 hours and the flight duration is 4 hours.")
    elif(choice_1 == 'Charlottesville, VA' and choice_2 == 'Ottawa, ON'):
        print("The time difference is 0 hours and the flight duration is 14.75 hours.")
    elif(choice_1 == 'Charlottesville, VA' and choice_2 == 'Dublin, IE'):
        print("The time difference is 5 hours and the flight duration is 7.75 hours.")
    elif(choice_1 == 'Charlottesville, VA' and choice_2 == 'Twin Cities, MN'):
        print("The time difference is 1 hour and the flight duration is 2 hours.")
    elif(choice_1 == 'Charlottesville, VA' and choice_2 == 'Rochester, NY'):
        print("The time difference is 0 hours and the flight duration is 1 hour.")
#ALL COMBOS STARTING WITH OTTAWA, ON
    elif(choice_1 == 'Ottawa, ON' and choice_2 == 'Ottawa, ON'):
        print("The time difference is 0 hours and the flight duration is 0 hours.")
    elif(choice_1 == 'Ottawa, ON' and choice_2 == 'Orlando, FL'):
        print("The time difference is 0 hours and the flight duration is 14 hours.")
    elif(choice_1 == 'Ottawa, ON' and choice_2 == 'Southampton, UK'):
        print("The time difference is 5 hours and the flight duration is 7 hours.")
    elif(choice_1 == 'Ottawa, ON' and choice_2 == 'Tempe, AZ'):
        print("The time difference is 3 hours and the flight duration is 15 hours.")
    elif(choice_1 == 'Ottawa, ON' and choice_2 == 'Washington, DC'):
        print("The time difference is 0 hours and the flight duration is 13 hours.")
    elif(choice_1 == 'Ottawa, ON' and choice_2 == 'Berkeley, CA'):
        print("The time difference is 3 hours and the flight duration is 14 hours.")
    elif(choice_1 == 'Ottawa, ON' and choice_2 == 'Southampton, UK'):
        print("The time difference is 5 hours and the flight duration is 7 hours.")
    elif(choice_1 == 'Ottawa, ON' and choice_2 == 'Philadelphia, PA'):
        print("The time difference is 0 hours and the flight duration is 12.75 hours.")
    elif(choice_1 == 'Ottawa, ON' and choice_2 == 'Montreal, QC'):
        print("The time difference is 0 hours and the flight duration is 12 hours.")
    elif(choice_1 == 'Ottawa, ON' and choice_2 == 'Orlando, FL'):
        print("The time difference is 0 hours and the flight duration is 14 hours.")
    elif(choice_1 == 'Ottawa, ON' and choice_2 == 'Austin, TX'):
        print("The time difference is 1 hour and the flight duration is 15 hours.")
    elif(choice_1 == 'Ottawa, ON' and choice_2 == 'Las Vegas, NV'):
        print("The time difference is 3 hours and the flight duration is 14.5 hours.")
    elif(choice_1 == 'Ottawa, ON' and choice_2 == 'Dublin, IE'):
        print("The time difference is 1 hour and the flight duration is 8 hours.")
    elif(choice_1 == 'Ottawa, ON' and choice_2 == 'Twin Cities, MN'):
        print("The time difference is 1 hour and the flight duration is 13.75 hours.")
    elif(choice_1 == 'Ottawa, ON' and choice_2 == 'Charlottesville, VA'):
        print("The time difference is 0 hours and the flight duration is 14.75 hours.")
    elif(choice_1 == 'Ottawa, ON' and choice_2 == 'Rochester, NY'):
        print("The time difference is 0 hours and the flight duration is 14. hours.")
    else:
        print("Error! Please Enter locations from the list in the correct format.")
# Out:
# Enter a first location: Rochester, NY
# Enter a second location: Rochester, NY
# You chose Rochester, NY and Rochester, NY
# The time difference is 0 hours and the flight duration is 0 hours.
